# %% [markdown]
# Midterm Problem 2
#
# Dorsa Erfani

# %%
import numpy as np
import matplotlib.pyplot as plt
from time import process_time_ns
from timeit import timeit
# %matplotlib inline
from scipy.optimize import curve_fit
from scipy.interpolate import CubicSpline
from scipy.interpolate import interp1d
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import max_error

# %% [markdown]
# Consider the two-body orbit problem. The relationship between the time t and the angle ξ of the motion is given by
#
# t = T(ξ−esinξ). 2π
#
# The parameters in these equations have values T = 1, a = 1, e = 0.9, and m1 = 0.25m2.
# ** Provide all code used to produce your answers. Put comments in the code describing all significant steps.

# %% [markdown]
# (A) (5 points) For a value of t = 1, solve for the value of ξ to a precision of 1e-6, without using any package.

# %%
#PART A

# defining the function and setting it = 0 
def f(e, t):
    return (1/(2*np.pi))*(e - 0.9*np.sin(e))-t

#defining the position eqns: 

def x1(e):
    return 0.8*1*(np.cos(e-0.9))
def y1(e):
    return 0.8*1*np.sqrt(1-(0.9**2))*np.sin(e)
def x2(e):
    return -0.2*1*(np.cos(e-0.9))
def y2(e):
    return -0.2*1*np.sqrt(1-(0.9**2))*np.sin(e)

# %%
#  e=x
def nraphson (fn, x, tol=1.0e-6, maxiter=100): # defining the nraph function and setting 
    for i in range(maxiter):                  #up parameters for tolerence and maximum iteration
        xnew = x - fn[0](x)/fn[1](x)
        if abs(xnew - x) < tol: break
        x=xnew
    return xnew, i

#using the lambda function to define f(x) and f'(x)
y= [lambda x: (1/(2*np.pi))*(x - 0.9*np.sin(x))-1, lambda x: (1/(2*np.pi))*(-0.9*np.cos(x)+1)]



#calling the nraph function and making a guess to find the root
x, n = nraphson(y, 5)
print('the root is %f at %d iterations' % (x,n))
# Out:
# the root is 6.283185 at 5 iterations

# %% [markdown]
# answer to part A: the value of e is 6.283185, when t = 1, to a precision of 1e-6

# %% [markdown]
# (B) (8 points) Plot ξ as a function of t. Solve for ξ for a range of time points. Plot the positions of both particles at each time. Calculate sufficient time points that the particles complete one elliptical orbit.

# %%
#PART B
tv= np.linspace(0,180, 1000)

# %%
ynn = []
for i in range (len(tv)):
    def raphson (fn, x, tol=1.0e-6, maxiter=100): # defining the nraph function and setting 
        for i in range(maxiter):                  #up parameters for tolerence and maximum iteration
            xnew = x - fn[0](x)/fn[1](x)
            if abs(xnew - x) < tol: break
            x=xnew
        return xnew, i
    ym= [lambda x: (1/(2*np.pi))*(x - 0.9*np.sin(x))-tv[i] , lambda x: (1/(2*np.pi))*(-0.9*np.cos(x)+tv[i])]
    x, n = nraphson(ym, [i])
    ynn.append(x)
    
    print('the root is %f at %d iterations' % (x,n))
#print(ynn)
# Out:
# the root is 11663529284007984.000000 at 99 iterations
# the root is -1510697.665883 at 99 iterations
# the root is 2.671713 at 91 iterations
# the root is 3.275848 at 14 iterations
# the root is 1243712352.387508 at 99 iterations
# the root is 4.761618 at 8 iterations
# the root is 7.678869 at 9 iterations
# the root is 8.591104 at 9 iterations
# the root is 9.230551 at 10 iterations
# the root is 9.832271 at 12 iterations
# the root is 10.520657 at 16 iterations
# the root is 11.889299 at 57 iterations
# the root is 14.443396 at 19 iterations
# the root is 15.174803 at 17 iterations
# the root is 15.782477 at 18 iterations
# the root is 16.404308 at 22 iterations
# the root is 17.215490 at 36 iterations
# the root is 20.100009 at 43 iterations
# the root is 21.085849 at 26 iterations
# the root is 21.736618 at 24 iterations
# the root is 22.337007 at 27 iterations
# the root is 23.008548 at 35 iterations
# the root is 24.165157 at 97 iterations
# the root is 26.917841 at 39 iterations
# the root is 27.676845 at 31 iterations
# the root is 28.289232 at 31 iterations
# the root is 28.904439 at 36 iterations
# the root is 29.679210 at 56 iterations
# the root is 32.490334 at 82 iterations
# the root is 33.578179 at 38 iterations
# the root is 34.242241 at 35 iterations
# the root is 34.842365 at 38 iterations
# the root is 35.499517 at 48 iterations
# the root is 36.531747 at 99 iterations
# the root is 39.385568 at 58 iterations
# the root is 40.177656 at 39 iterations
# the root is 40.796012 at 37 iterations
# the root is 41.405891 at 45 iterations
# the root is 42.150495 at 64 iterations
# the root is 44.819317 at 99 iterations
# the root is 46.067666 at 60 iterations
# the root is 46.747297 at 48 iterations
# the root is 47.348217 at 45 iterations
# the root is 47.993102 at 35 iterations
# the root is 48.939478 at 82 iterations
# the root is 51.844704 at 99 iterations
# the root is 52.677047 at 64 iterations
# the root is 53.302709 at 56 iterations
# the root is 53.908471 at 58 iterations
# the root is 54.627759 at 73 iterations
# the root is 56.666115 at 99 iterations
# the root is 58.553804 at 90 iterations
# the root is 59.251672 at 68 iterations
# the root is 59.854462 at 64 iterations
# the root is 60.488912 at 72 iterations
# the root is 61.371203 at 99 iterations
# the root is 64.290196 at 99 iterations
# the root is 65.174784 at 88 iterations
# the root is 65.809235 at 74 iterations
# the root is 66.412025 at 75 iterations
# the root is 67.109890 at 93 iterations
# the root is 68.572597 at 99 iterations
# the root is 71.035772 at 99 iterations
# the root is 71.755226 at 90 iterations
# the root is 72.360989 at 82 iterations
# the root is 72.986649 at 88 iterations
# the root is 73.818787 at 99 iterations
# the root is 76.673043 at 99 iterations
# the root is 77.670551 at 99 iterations
# the root is 78.315480 at 94 iterations
# the root is 78.916401 at 92 iterations
# the root is 79.596013 at 99 iterations
# the root is 80.807498 at 99 iterations
# the root is 83.509555 at 99 iterations
# the root is 84.257775 at 99 iterations
# the root is 84.867689 at 99 iterations
# the root is 85.486032 at 99 iterations
# the root is 86.277582 at 99 iterations
# the root is 88.803721 at 99 iterations
# the root is 90.163239 at 99 iterations
# the root is 90.821290 at 99 iterations
# the root is 91.421441 at 99 iterations
# the root is 92.085401 at 99 iterations
# the root is 93.150516 at 99 iterations
# the root is 95.952771 at 99 iterations
# the root is 96.758741 at 99 iterations
# the root is 97.374384 at 99 iterations
# the root is 97.986752 at 99 iterations
# the root is 98.744497 at 99 iterations
# the root is 100.698021 at 99 iterations
# the root is 102.647542 at 99 iterations
# the root is 103.326224 at 99 iterations
# the root is 103.926889 at 99 iterations
# the root is 104.577326 at 99 iterations
# the root is 105.541564 at 99 iterations
# the root is 108.286438 at 99 iterations
# the root is 109.255784 at 99 iterations
# the root is 109.880632 at 99 iterations
# the root is 110.488373 at 99 iterations
# the root is 111.217161 at 99 iterations
# the root is 112.729201 at 99 iterations
# the root is 115.102575 at 99 iterations
# the root is 115.828740 at 99 iterations
# the root is 116.432195 at 99 iterations
# the root is 117.070922 at 99 iterations
# the root is 117.959095 at 99 iterations
# the root is 120.386335 at 99 iterations
# the root is 121.740190 at 99 iterations
# the root is 122.385094 at 99 iterations
# the root is 122.990109 at 99 iterations
# the root is 123.693673 at 99 iterations
# the root is 124.938047 at 99 iterations
# the root is 127.469902 at 99 iterations
# the root is 128.323647 at 99 iterations
# the root is 128.935956 at 99 iterations
# the root is 129.565005 at 99 iterations
# the root is 130.392973 at 99 iterations
# the root is 132.338342 at 99 iterations
# the root is 134.186953 at 99 iterations
# the root is 134.883820 at 99 iterations
# the root is 135.490305 at 99 iterations
# the root is 136.172022 at 99 iterations
# the root is 137.245323 at 99 iterations
# the root is 139.667561 at 99 iterations
# the root is 140.797225 at 99 iterations
# the root is 141.434630 at 99 iterations
# the root is 142.057470 at 99 iterations
# the root is 142.836261 at 99 iterations
# the root is 144.375343 at 99 iterations
# the root is 146.548946 at 99 iterations
# the root is 147.367626 at 99 iterations
# the root is 147.985445 at 99 iterations
# the root is 148.649282 at 99 iterations
# the root is 149.602522 at 99 iterations
# the root is 151.693057 at 99 iterations
# the root is 153.223295 at 99 iterations
# the root is 153.921178 at 99 iterations
# the root is 154.544669 at 99 iterations
# the root is 155.282935 at 99 iterations
# the root is 156.540878 at 99 iterations
# the root is 158.766670 at 99 iterations
# the root is 159.819926 at 99 iterations
# the root is 160.469698 at 99 iterations
# the root is 161.121617 at 99 iterations
# the root is 161.984960 at 99 iterations
# the root is 163.676102 at 99 iterations
# the root is 165.558614 at 99 iterations
# the root is 166.383781 at 99 iterations
# the root is 167.021650 at 99 iterations
# the root is 167.728166 at 99 iterations
# the root is 168.793327 at 99 iterations
# the root is 170.814429 at 99 iterations
# the root is 172.211206 at 99 iterations
# the root is 172.933879 at 99 iterations
# the root is 173.584849 at 99 iterations
# the root is 174.380442 at 99 iterations
# the root is 175.739574 at 99 iterations
# the root is 177.746455 at 99 iterations
# the root is 178.800901 at 99 iterations
# the root is 179.480818 at 99 iterations
# the root is 180.167846 at 99 iterations
# the root is 181.099542 at 99 iterations
# the root is 182.780914 at 99 iterations
# the root is 184.493915 at 99 iterations
# the root is 185.361078 at 99 iterations
# the root is 186.032252 at 99 iterations
# the root is 186.780837 at 99 iterations
# the root is 187.906602 at 99 iterations
# the root is 189.774986 at 99 iterations
# the root is 191.136338 at 99 iterations
# the root is 191.908067 at 99 iterations
# the root is 192.594977 at 99 iterations
# the root is 193.435935 at 99 iterations
# the root is 194.802426 at 99 iterations
# the root is 196.627297 at 99 iterations
# the root is 197.723575 at 99 iterations
# the root is 198.451426 at 99 iterations
# the root is 199.175848 at 99 iterations
# the root is 200.145601 at 99 iterations
# the root is 201.737743 at 99 iterations
# the root is 203.351025 at 99 iterations
# the root is 204.281808 at 99 iterations
# the root is 204.997875 at 99 iterations
# the root is 205.782071 at 99 iterations
# the root is 206.916673 at 99 iterations
# the root is 208.629397 at 99 iterations
# the root is 209.990014 at 99 iterations
# the root is 210.825402 at 99 iterations
# the root is 211.552905 at 99 iterations
# the root is 212.420744 at 99 iterations
# the root is 213.738928 at 99 iterations
# the root is 215.427164 at 99 iterations
# the root is 216.577951 at 99 iterations
# the root is 217.363089 at 99 iterations
# the root is 218.121442 at 99 iterations
# the root is 219.097130 at 99 iterations
# the root is 220.577501 at 99 iterations
# the root is 222.132445 at 99 iterations
# the root is 223.135729 at 99 iterations
# the root is 223.900814 at 99 iterations
# the root is 224.707947 at 99 iterations
# the root is 225.811244 at 99 iterations
# the root is 227.386582 at 99 iterations
# the root is 228.767908 at 99 iterations
# the root is 229.676056 at 99 iterations
# the root is 230.443040 at 99 iterations
# the root is 231.316040 at 99 iterations
# the root is 232.553747 at 99 iterations
# the root is 234.136007 at 99 iterations
# the root is 235.355656 at 99 iterations
# the root is 236.206971 at 99 iterations
# the root is 236.993304 at 99 iterations
# the root is 237.947590 at 99 iterations
# the root is 239.305012 at 99 iterations
# the root is 240.820277 at 99 iterations
# the root is 241.911829 at 99 iterations
# the root is 242.733842 at 99 iterations
# the root is 243.554373 at 99 iterations
# the root is 244.601373 at 99 iterations
# the root is 246.041066 at 99 iterations
# the root is 247.448568 at 99 iterations
# the root is 248.447325 at 99 iterations
# the root is 249.260424 at 99 iterations
# the root is 250.128109 at 99 iterations
# the root is 251.271838 at 99 iterations
# the root is 252.743182 at 99 iterations
# the root is 254.033729 at 99 iterations
# the root is 254.969436 at 99 iterations
# the root is 255.789387 at 99 iterations
# the root is 256.715125 at 99 iterations
# the root is 257.949055 at 99 iterations
# the root is 259.403089 at 99 iterations
# the root is 260.587161 at 99 iterations
# the root is 261.483102 at 99 iterations
# the root is 262.322551 at 99 iterations
# the root is 263.314358 at 99 iterations
# the root is 264.620653 at 99 iterations
# the root is 266.021415 at 99 iterations
# the root is 267.117637 at 99 iterations
# the root is 267.991726 at 99 iterations
# the root is 268.860951 at 99 iterations
# the root is 269.922738 at 99 iterations
# the root is 271.275129 at 99 iterations
# the root is 272.603414 at 99 iterations
# the root is 273.631556 at 99 iterations
# the root is 274.497655 at 99 iterations
# the root is 275.404811 at 99 iterations
# the root is 276.535257 at 99 iterations
# the root is 277.904611 at 99 iterations
# the root is 279.155594 at 99 iterations
# the root is 280.133510 at 99 iterations
# the root is 281.002464 at 99 iterations
# the root is 281.953498 at 99 iterations
# the root is 283.145619 at 99 iterations
# the root is 284.505666 at 99 iterations
# the root is 285.684004 at 99 iterations
# the root is 286.626778 at 99 iterations
# the root is 287.507126 at 99 iterations
# the root is 288.505515 at 99 iterations
# the root is 289.747345 at 99 iterations
# the root is 291.078435 at 99 iterations
# the root is 292.193648 at 99 iterations
# the root is 293.113685 at 99 iterations
# the root is 294.012095 at 99 iterations
# the root is 295.058601 at 99 iterations
# the root is 296.334947 at 99 iterations
# the root is 297.625170 at 99 iterations
# the root is 298.688445 at 99 iterations
# the root is 299.595851 at 99 iterations
# the root is 300.517372 at 99 iterations
# the root is 301.609960 at 99 iterations
# the root is 302.904680 at 99 iterations
# the root is 304.148990 at 99 iterations
# the root is 305.171367 at 99 iterations
# the root is 306.074355 at 99 iterations
# the root is 307.022546 at 99 iterations
# the root is 308.156593 at 99 iterations
# the root is 309.454701 at 99 iterations
# the root is 310.653104 at 99 iterations
# the root is 311.644621 at 99 iterations
# the root is 312.549843 at 99 iterations
# the root is 313.526853 at 99 iterations
# the root is 314.695661 at 99 iterations
# the root is 315.984765 at 99 iterations
# the root is 317.140426 at 99 iterations
# the root is 318.109814 at 99 iterations
# the root is 319.022610 at 99 iterations
# the root is 320.029240 at 99 iterations
# the root is 321.224794 at 99 iterations
# the root is 322.495723 at 99 iterations
# the root is 323.613438 at 99 iterations
# the root is 324.568082 at 99 iterations
# the root is 325.492652 at 99 iterations
# the root is 326.528456 at 99 iterations
# the root is 327.742264 at 99 iterations
# the root is 328.989042 at 99 iterations
# the root is 330.074179 at 99 iterations
# the root is 331.020196 at 99 iterations
# the root is 331.959722 at 99 iterations
# the root is 333.023157 at 99 iterations
# the root is 334.247028 at 99 iterations
# the root is 335.466435 at 99 iterations
# the root is 336.524288 at 99 iterations
# the root is 337.466644 at 99 iterations
# the root is 338.423378 at 99 iterations
# the root is 339.512008 at 99 iterations
# the root is 340.738650 at 99 iterations
# the root is 341.929622 at 99 iterations
# the root is 342.965073 at 99 iterations
# the root is 343.907703 at 99 iterations
# the root is 344.883034 at 99 iterations
# the root is 345.993778 at 99 iterations
# the root is 347.217170 at 99 iterations
# the root is 348.380202 at 99 iterations
# the root is 349.397572 at 99 iterations
# the root is 350.343490 at 99 iterations
# the root is 351.338019 at 99 iterations
# the root is 352.467412 at 99 iterations
# the root is 353.682954 at 99 iterations
# the root is 354.819587 at 99 iterations
# the root is 355.822603 at 99 iterations
# the root is 356.774015 at 99 iterations
# the root is 357.787629 at 99 iterations
# the root is 358.932075 at 99 iterations
# the root is 360.136561 at 99 iterations
# the root is 361.248982 at 99 iterations
# the root is 362.240812 at 99 iterations
# the root is 363.199220 at 99 iterations
# the root is 364.231185 at 99 iterations
# the root is 365.387166 at 99 iterations
# the root is 366.578643 at 99 iterations
# the root is 367.669386 at 99 iterations
# the root is 368.652707 at 99 iterations
# the root is 369.619016 at 99 iterations
# the root is 370.668076 at 99 iterations
# the root is 371.832312 at 99 iterations
# the root is 373.009866 at 99 iterations
# the root is 374.081615 at 99 iterations
# the root is 375.058679 at 99 iterations
# the root is 376.033304 at 99 iterations
# the root is 377.097800 at 99 iterations
# the root is 378.267343 at 99 iterations
# the root is 379.430869 at 99 iterations
# the root is 380.486311 at 99 iterations
# the root is 381.459023 at 99 iterations
# the root is 382.441997 at 99 iterations
# the root is 383.519986 at 99 iterations
# the root is 384.692264 at 99 iterations
# the root is 385.842242 at 99 iterations
# the root is 386.883977 at 99 iterations
# the root is 387.853955 at 99 iterations
# the root is 388.845026 at 99 iterations
# the root is 389.934398 at 99 iterations
# the root is 391.107221 at 99 iterations
# the root is 392.244508 at 99 iterations
# the root is 393.274986 at 99 iterations
# the root is 394.243616 at 99 iterations
# the root is 395.242347 at 99 iterations
# the root is 396.340942 at 99 iterations
# the root is 397.512468 at 99 iterations
# the root is 398.638134 at 99 iterations
# the root is 399.659612 at 99 iterations
# the root is 400.628087 at 99 iterations
# the root is 401.633931 at 99 iterations
# the root is 402.739639 at 99 iterations
# the root is 403.908346 at 99 iterations
# the root is 405.023530 at 99 iterations
# the root is 406.038046 at 99 iterations
# the root is 407.007395 at 99 iterations
# the root is 408.019766 at 99 iterations
# the root is 409.130614 at 99 iterations
# the root is 410.295255 at 99 iterations
# the root is 411.401066 at 99 iterations
# the root is 412.410413 at 99 iterations
# the root is 413.381521 at 99 iterations
# the root is 414.399844 at 99 iterations
# the root is 415.514061 at 99 iterations
# the root is 416.673634 at 99 iterations
# the root is 417.771078 at 99 iterations
# the root is 418.776794 at 99 iterations
# the root is 419.750411 at 99 iterations
# the root is 420.774158 at 99 iterations
# the root is 421.890221 at 99 iterations
# the root is 423.043945 at 99 iterations
# the root is 424.133886 at 99 iterations
# the root is 425.137241 at 99 iterations
# the root is 426.113985 at 99 iterations
# the root is 427.142695 at 99 iterations
# the root is 428.259356 at 99 iterations
# the root is 429.406656 at 99 iterations
# the root is 430.489798 at 99 iterations
# the root is 431.491793 at 99 iterations
# the root is 432.472146 at 99 iterations
# the root is 433.505430 at 99 iterations
# the root is 434.621725 at 99 iterations
# the root is 435.762223 at 99 iterations
# the root is 436.839119 at 99 iterations
# the root is 437.840489 at 99 iterations
# the root is 438.824792 at 99 iterations
# the root is 439.862332 at 99 iterations
# the root is 440.977568 at 99 iterations
# the root is 442.111082 at 99 iterations
# the root is 443.182156 at 99 iterations
# the root is 444.183385 at 99 iterations
# the root is 445.171826 at 99 iterations
# the root is 446.213357 at 99 iterations
# the root is 447.327100 at 99 iterations
# the root is 448.453630 at 99 iterations
# the root is 449.519211 at 99 iterations
# the root is 450.520556 at 99 iterations
# the root is 451.513170 at 99 iterations
# the root is 452.558461 at 99 iterations
# the root is 453.670496 at 99 iterations
# the root is 454.790223 at 99 iterations
# the root is 455.850587 at 99 iterations
# the root is 456.852110 at 99 iterations
# the root is 457.848771 at 99 iterations
# the root is 458.897598 at 99 iterations
# the root is 460.007896 at 99 iterations
# the root is 461.121163 at 99 iterations
# the root is 462.176570 at 99 iterations
# the root is 463.178181 at 99 iterations
# the root is 464.178610 at 99 iterations
# the root is 465.230732 at 99 iterations
# the root is 466.339404 at 99 iterations
# the root is 467.446701 at 99 iterations
# the root is 468.497432 at 99 iterations
# the root is 469.498937 at 99 iterations
# the root is 470.502714 at 99 iterations
# the root is 471.557843 at 99 iterations
# the root is 472.665093 at 99 iterations
# the root is 473.767030 at 99 iterations
# the root is 474.813415 at 99 iterations
# the root is 475.814565 at 99 iterations
# the root is 476.821151 at 99 iterations
# the root is 477.878933 at 99 iterations
# the root is 478.985013 at 99 iterations
# the root is 480.082292 at 99 iterations
# the root is 481.124729 at 99 iterations
# the root is 482.125268 at 99 iterations
# the root is 483.134039 at 99 iterations
# the root is 484.194039 at 99 iterations
# the root is 485.299199 at 99 iterations
# the root is 486.392582 at 99 iterations
# the root is 487.431545 at 99 iterations
# the root is 488.431253 at 99 iterations
# the root is 489.441534 at 99 iterations
# the root is 490.503231 at 99 iterations
# the root is 491.607682 at 99 iterations
# the root is 492.697955 at 99 iterations
# the root is 493.733994 at 99 iterations
# the root is 494.732720 at 99 iterations
# the root is 495.743830 at 99 iterations
# the root is 496.806623 at 99 iterations
# the root is 497.910500 at 99 iterations
# the root is 498.998434 at 99 iterations
# the root is 500.032162 at 99 iterations
# the root is 501.029849 at 99 iterations
# the root is 502.041142 at 99 iterations
# the root is 503.104371 at 99 iterations
# the root is 504.207703 at 99 iterations
# the root is 505.294020 at 99 iterations
# the root is 506.326100 at 99 iterations
# the root is 507.322797 at 99 iterations
# the root is 508.333701 at 99 iterations
# the root is 509.396667 at 99 iterations
# the root is 510.499368 at 99 iterations
# the root is 511.584703 at 99 iterations
# the root is 512.615822 at 99 iterations
# the root is 513.611688 at 99 iterations
# the root is 514.621734 at 99 iterations
# the root is 515.683737 at 99 iterations
# the root is 516.785600 at 99 iterations
# the root is 517.870474 at 99 iterations
# the root is 518.901315 at 99 iterations
# the root is 519.896609 at 99 iterations
# the root is 520.905456 at 99 iterations
# the root is 521.965832 at 99 iterations
# the root is 523.066538 at 99 iterations
# the root is 524.151332 at 99 iterations
# the root is 525.182543 at 99 iterations
# the root is 526.177613 at 99 iterations
# the root is 527.185058 at 99 iterations
# the root is 528.243214 at 99 iterations
# the root is 529.342358 at 99 iterations
# the root is 530.427296 at 99 iterations
# the root is 531.459464 at 99 iterations
# the root is 532.454720 at 99 iterations
# the root is 533.460701 at 99 iterations
# the root is 534.516144 at 99 iterations
# the root is 535.613263 at 99 iterations
# the root is 536.698414 at 99 iterations
# the root is 537.732030 at 99 iterations
# the root is 538.727920 at 99 iterations
# the root is 539.732506 at 99 iterations
# the root is 540.784871 at 99 iterations
# the root is 541.879486 at 99 iterations
# the root is 542.964764 at 99 iterations
# the root is 544.000203 at 99 iterations
# the root is 544.997183 at 99 iterations
# the root is 546.000558 at 99 iterations
# the root is 547.049619 at 99 iterations
# the root is 548.141270 at 99 iterations
# the root is 549.226461 at 99 iterations
# the root is 550.263964 at 99 iterations
# the root is 551.262464 at 99 iterations
# the root is 552.264907 at 99 iterations
# the root is 553.310580 at 99 iterations
# the root is 554.398867 at 99 iterations
# the root is 555.483654 at 99 iterations
# the root is 556.523318 at 99 iterations
# the root is 557.523715 at 99 iterations
# the root is 558.525566 at 99 iterations
# the root is 559.567905 at 99 iterations
# the root is 560.652518 at 99 iterations
# the root is 561.736521 at 99 iterations
# the root is 562.778302 at 99 iterations
# the root is 563.780892 at 99 iterations
# the root is 564.782524 at 99 iterations
# the root is 565.821705 at 99 iterations
# the root is 566.902447 at 99 iterations
# the root is 567.985263 at 99 iterations
# the root is 569.028987 at 99 iterations
# the root is 570.033965 at 99 iterations
# the root is 571.035751 at 99 iterations
# the root is 572.072050 at 99 iterations
# the root is 573.148846 at 99 iterations
# the root is 574.230093 at 99 iterations
# the root is 575.275481 at 99 iterations
# the root is 576.282925 at 99 iterations
# the root is 577.285207 at 99 iterations
# the root is 578.318974 at 99 iterations
# the root is 579.391874 at 99 iterations
# the root is 580.471226 at 99 iterations
# the root is 581.517924 at 99 iterations
# the root is 582.527796 at 99 iterations
# the root is 583.530854 at 99 iterations
# the root is 584.562475 at 99 iterations
# the root is 585.631648 at 99 iterations
# the root is 586.708863 at 99 iterations
# the root is 587.756483 at 99 iterations
# the root is 588.768630 at 99 iterations
# the root is 589.772662 at 99 iterations
# the root is 590.802533 at 99 iterations
# the root is 591.868244 at 99 iterations
# the root is 592.943188 at 99 iterations
# the root is 593.991343 at 99 iterations
# the root is 595.005517 at 99 iterations
# the root is 596.010620 at 99 iterations
# the root is 597.039109 at 99 iterations
# the root is 598.101699 at 99 iterations
# the root is 599.174353 at 99 iterations
# the root is 600.222696 at 99 iterations
# the root is 601.238581 at 99 iterations
# the root is 602.244743 at 99 iterations
# the root is 603.272163 at 99 iterations
# the root is 604.332014 at 99 iterations
# the root is 605.402471 at 99 iterations
# the root is 606.450730 at 99 iterations
# the root is 607.467971 at 99 iterations
# the root is 608.475079 at 99 iterations
# the root is 609.501658 at 99 iterations
# the root is 610.559165 at 99 iterations
# the root is 611.627621 at 99 iterations
# the root is 612.675619 at 99 iterations
# the root is 613.693862 at 99 iterations
# the root is 614.701707 at 99 iterations
# the root is 615.727575 at 99 iterations
# the root is 616.783108 at 99 iterations
# the root is 617.849840 at 99 iterations
# the root is 618.897512 at 99 iterations
# the root is 619.916436 at 99 iterations
# the root is 620.924743 at 99 iterations
# the root is 621.949918 at 99 iterations
# the root is 623.003792 at 99 iterations
# the root is 624.069130 at 99 iterations
# the root is 625.116525 at 99 iterations
# the root is 626.135878 at 99 iterations
# the root is 627.144331 at 99 iterations
# the root is 628.168723 at 99 iterations
# the root is 629.221166 at 99 iterations
# the root is 630.285462 at 99 iterations
# the root is 631.332738 at 99 iterations
# the root is 632.352362 at 99 iterations
# the root is 633.360642 at 99 iterations
# the root is 634.384057 at 99 iterations
# the root is 635.435193 at 99 iterations
# the root is 636.498786 at 99 iterations
# the root is 637.546194 at 99 iterations
# the root is 638.566040 at 99 iterations
# the root is 639.573857 at 99 iterations
# the root is 640.596026 at 99 iterations
# the root is 641.645858 at 99 iterations
# the root is 642.709039 at 99 iterations
# the root is 643.756897 at 99 iterations
# the root is 644.777035 at 99 iterations
# the root is 645.784166 at 99 iterations
# the root is 646.804769 at 99 iterations
# the root is 647.853175 at 99 iterations
# the root is 648.916153 at 99 iterations
# the root is 649.964819 at 99 iterations
# the root is 650.985437 at 99 iterations
# the root is 651.991748 at 99 iterations
# the root is 653.010451 at 99 iterations
# the root is 654.057195 at 99 iterations
# the root is 655.120072 at 99 iterations
# the root is 656.169907 at 99 iterations
# the root is 657.191297 at 99 iterations
# the root is 658.196767 at 99 iterations
# the root is 659.213258 at 99 iterations
# the root is 660.258004 at 99 iterations
# the root is 661.320754 at 99 iterations
# the root is 662.372088 at 99 iterations
# the root is 663.394626 at 99 iterations
# the root is 664.399359 at 99 iterations
# the root is 665.413385 at 99 iterations
# the root is 666.455729 at 99 iterations
# the root is 667.518187 at 99 iterations
# the root is 668.571281 at 99 iterations
# the root is 669.595402 at 99 iterations
# the root is 670.599627 at 99 iterations
# the root is 671.611022 at 99 iterations
# the root is 672.650528 at 99 iterations
# the root is 673.712393 at 99 iterations
# the root is 674.767408 at 99 iterations
# the root is 675.793572 at 99 iterations
# the root is 676.797634 at 99 iterations
# the root is 677.806350 at 99 iterations
# the root is 678.842585 at 99 iterations
# the root is 679.903433 at 99 iterations
# the root is 680.960402 at 99 iterations
# the root is 681.989059 at 99 iterations
# the root is 682.993407 at 99 iterations
# the root is 683.999523 at 99 iterations
# the root is 685.032101 at 99 iterations
# the root is 686.091409 at 99 iterations
# the root is 687.150218 at 99 iterations
# the root is 688.181774 at 99 iterations
# the root is 689.186932 at 99 iterations
# the root is 690.190662 at 99 iterations
# the root is 691.219282 at 99 iterations
# the root is 692.276461 at 99 iterations
# the root is 693.336845 at 99 iterations
# the root is 694.371620 at 99 iterations
# the root is 695.378162 at 99 iterations
# the root is 696.379853 at 99 iterations
# the root is 697.404326 at 99 iterations
# the root is 698.458763 at 99 iterations
# the root is 699.520305 at 99 iterations
# the root is 700.558508 at 99 iterations
# the root is 701.567024 at 99 iterations
# the root is 702.567141 at 99 iterations
# the root is 703.587411 at 99 iterations
# the root is 704.638514 at 99 iterations
# the root is 705.700664 at 99 iterations
# the root is 706.742365 at 99 iterations
# the root is 707.753423 at 99 iterations
# the root is 708.752529 at 99 iterations
# the root is 709.768688 at 99 iterations
# the root is 710.815927 at 99 iterations
# the root is 711.878030 at 99 iterations
# the root is 712.923140 at 99 iterations
# the root is 713.937254 at 99 iterations
# the root is 714.935985 at 99 iterations
# the root is 715.948270 at 99 iterations
# the root is 716.991216 at 99 iterations
# the root is 718.052549 at 99 iterations
# the root is 719.100817 at 99 iterations
# the root is 720.118411 at 99 iterations
# the root is 721.117444 at 99 iterations
# the root is 722.126233 at 99 iterations
# the root is 723.164583 at 99 iterations
# the root is 724.224398 at 99 iterations
# the root is 725.275419 at 99 iterations
# the root is 726.296798 at 99 iterations
# the root is 727.296816 at 99 iterations
# the root is 728.302606 at 99 iterations
# the root is 729.336211 at 99 iterations
# the root is 730.393781 at 99 iterations
# the root is 731.447007 at 99 iterations
# the root is 732.472336 at 99 iterations
# the root is 733.473996 at 99 iterations
# the root is 734.477383 at 99 iterations
# the root is 735.506249 at 99 iterations
# the root is 736.560912 at 99 iterations
# the root is 737.615686 at 99 iterations
# the root is 738.644971 at 99 iterations
# the root is 739.648871 at 99 iterations
# the root is 740.650519 at 99 iterations
# the root is 741.674808 at 99 iterations
# the root is 742.726003 at 99 iterations
# the root is 743.781594 at 99 iterations
# the root is 744.814686 at 99 iterations
# the root is 745.821330 at 99 iterations
# the root is 746.821941 at 99 iterations
# the root is 747.841959 at 99 iterations
# the root is 748.889256 at 99 iterations
# the root is 749.944904 at 99 iterations
# the root is 750.981498 at 99 iterations
# the root is 751.991276 at 99 iterations
# the root is 752.991553 at 99 iterations
# the root is 754.007729 at 99 iterations
# the root is 755.050849 at 99 iterations
# the root is 756.105804 at 99 iterations
# the root is 757.145464 at 99 iterations
# the root is 758.158630 at 99 iterations
# the root is 759.159247 at 99 iterations
# the root is 760.172109 at 99 iterations
# the root is 761.210929 at 99 iterations
# the root is 762.264496 at 99 iterations
# the root is 763.306678 at 99 iterations
# the root is 764.323342 at 99 iterations
# the root is 765.324911 at 99 iterations
# the root is 766.335053 at 99 iterations
# the root is 767.369603 at 99 iterations
# the root is 768.421177 at 99 iterations
# the root is 769.465267 at 99 iterations
# the root is 770.485394 at 99 iterations
# the root is 771.488440 at 99 iterations
# the root is 772.496491 at 99 iterations
# the root is 773.526940 at 99 iterations
# the root is 774.576034 at 99 iterations
# the root is 775.621384 at 99 iterations
# the root is 776.644803 at 99 iterations
# the root is 777.649744 at 99 iterations
# the root is 778.656332 at 99 iterations
# the root is 779.682969 at 99 iterations
# the root is 780.729227 at 99 iterations
# the root is 781.775195 at 99 iterations
# the root is 782.801623 at 99 iterations
# the root is 783.808754 at 99 iterations
# the root is 784.814479 at 99 iterations
# the root is 785.837683 at 99 iterations
# the root is 786.880888 at 99 iterations
# the root is 787.926875 at 99 iterations
# the root is 788.955937 at 99 iterations
# the root is 789.965429 at 99 iterations
# the root is 790.970833 at 99 iterations
# the root is 791.991045 at 99 iterations
# the root is 793.031113 at 99 iterations
# the root is 794.076594 at 99 iterations
# the root is 795.107857 at 99 iterations
# the root is 796.119759 at 99 iterations
# the root is 797.125305 at 99 iterations
# the root is 798.142996 at 99 iterations
# the root is 799.179964 at 99 iterations
# the root is 800.224505 at 99 iterations
# the root is 801.257514 at 99 iterations
# the root is 802.271768 at 99 iterations
# the root is 803.277822 at 99 iterations
# the root is 804.293461 at 99 iterations
# the root is 805.327465 at 99 iterations
# the root is 806.370740 at 99 iterations
# the root is 807.405049 at 99 iterations
# the root is 808.421508 at 99 iterations
# the root is 809.428337 at 99 iterations
# the root is 810.442362 at 99 iterations
# the root is 811.473612 at 99 iterations
# the root is 812.515402 at 99 iterations
# the root is 813.550602 at 99 iterations
# the root is 814.569058 at 99 iterations
# the root is 815.576828 at 99 iterations
# the root is 816.589626 at 99 iterations
# the root is 817.618373 at 99 iterations
# the root is 818.658563 at 99 iterations
# the root is 819.694304 at 99 iterations
# the root is 820.714518 at 99 iterations
# the root is 821.723303 at 99 iterations
# the root is 822.735190 at 99 iterations
# the root is 823.761705 at 99 iterations
# the root is 824.800262 at 99 iterations
# the root is 825.836270 at 99 iterations
# the root is 826.857998 at 99 iterations
# the root is 827.867797 at 99 iterations
# the root is 828.879012 at 99 iterations
# the root is 829.903551 at 99 iterations
# the root is 830.940511 at 99 iterations
# the root is 831.976591 at 99 iterations
# the root is 832.999611 at 99 iterations
# the root is 834.010372 at 99 iterations
# the root is 835.021074 at 99 iterations
# the root is 836.043859 at 99 iterations
# the root is 837.079298 at 99 iterations
# the root is 838.115330 at 99 iterations
# the root is 839.139463 at 99 iterations
# the root is 840.151108 at 99 iterations
# the root is 841.161384 at 99 iterations
# the root is 842.182586 at 99 iterations
# the root is 843.216593 at 99 iterations
# the root is 844.252524 at 99 iterations
# the root is 845.277647 at 99 iterations
# the root is 846.290096 at 99 iterations
# the root is 847.299978 at 99 iterations
# the root is 848.319704 at 99 iterations
# the root is 849.352358 at 99 iterations
# the root is 850.388181 at 99 iterations
# the root is 851.414235 at 99 iterations
# the root is 852.427432 at 99 iterations
# the root is 853.436913 at 99 iterations
# the root is 854.455208 at 99 iterations
# the root is 855.486555 at 99 iterations
# the root is 856.522287 at 99 iterations
# the root is 857.549273 at 99 iterations
# the root is 858.563206 at 99 iterations
# the root is 859.572268 at 99 iterations
# the root is 860.589119 at 99 iterations
# the root is 861.619153 at 99 iterations
# the root is 862.654811 at 99 iterations
# the root is 863.682781 at 99 iterations
# the root is 864.697494 at 99 iterations
# the root is 865.706130 at 99 iterations
# the root is 866.721482 at 99 iterations
# the root is 867.750137 at 99 iterations
# the root is 868.785714 at 99 iterations
# the root is 869.814751 at 99 iterations
# the root is 870.830352 at 99 iterations
# the root is 871.838592 at 99 iterations
# the root is 872.852369 at 99 iterations
# the root is 873.879517 at 99 iterations
# the root is 874.914956 at 99 iterations
# the root is 875.945156 at 99 iterations
# the root is 876.961812 at 99 iterations
# the root is 877.969742 at 99 iterations
# the root is 878.981866 at 99 iterations
# the root is 880.007325 at 99 iterations
# the root is 881.042505 at 99 iterations
# the root is 882.073948 at 99 iterations
# the root is 883.091876 at 99 iterations
# the root is 884.099652 at 99 iterations
# the root is 885.110078 at 99 iterations
# the root is 886.133622 at 99 iterations
# the root is 887.168345 at 99 iterations
# the root is 888.201070 at 99 iterations
# the root is 889.220522 at 99 iterations
# the root is 890.228374 at 99 iterations
# the root is 891.237108 at 99 iterations
# the root is 892.258497 at 99 iterations
# the root is 893.292485 at 99 iterations
# the root is 894.326463 at 99 iterations
# the root is 895.347699 at 99 iterations
# the root is 896.355935 at 99 iterations
# the root is 897.363057 at 99 iterations
# the root is 898.382058 at 99 iterations
# the root is 899.414961 at 99 iterations
# the root is 900.450077 at 99 iterations
# the root is 901.473341 at 99 iterations
# the root is 902.482332 at 99 iterations
# the root is 903.488013 at 99 iterations
# the root is 904.504431 at 99 iterations
# the root is 905.535841 at 99 iterations
# the root is 906.571875 at 99 iterations
# the root is 907.597363 at 99 iterations
# the root is 908.607529 at 99 iterations
# the root is 909.612038 at 99 iterations
# the root is 910.625745 at 99 iterations
# the root is 911.655222 at 99 iterations
# the root is 912.691847 at 99 iterations
# the root is 913.719680 at 99 iterations
# the root is 914.731465 at 99 iterations
# the root is 915.735170 at 99 iterations
# the root is 916.746130 at 99 iterations
# the root is 917.773232 at 99 iterations
# the root is 918.810014 at 99 iterations
# the root is 919.840208 at 99 iterations
# the root is 920.854053 at 99 iterations
# the root is 921.857413 at 99 iterations
# the root is 922.865700 at 99 iterations
# the root is 923.890017 at 99 iterations
# the root is 924.926430 at 99 iterations
# the root is 925.958879 at 99 iterations
# the root is 926.975188 at 99 iterations
# the root is 927.978735 at 99 iterations
# the root is 928.984549 at 99 iterations
# the root is 930.005738 at 99 iterations
# the root is 931.041188 at 99 iterations
# the root is 932.075646 at 99 iterations
# the root is 933.094754 at 99 iterations
# the root is 934.099074 at 99 iterations
# the root is 935.102741 at 99 iterations
# the root is 936.120556 at 99 iterations
# the root is 937.154414 at 99 iterations
# the root is 938.190495 at 99 iterations
# the root is 939.212635 at 99 iterations
# the root is 940.218336 at 99 iterations
# the root is 941.220304 at 99 iterations
# the root is 942.234626 at 99 iterations
# the root is 943.266266 at 99 iterations
# the root is 944.303448 at 99 iterations
# the root is 945.328723 at 99 iterations
# the root is 946.336402 at 99 iterations
# the root is 947.337228 at 99 iterations
# the root is 948.348081 at 99 iterations
# the root is 949.376922 at 99 iterations
# the root is 950.414568 at 99 iterations
# the root is 951.442930 at 99 iterations
# the root is 952.453137 at 99 iterations
# the root is 953.453466 at 99 iterations
# the root is 954.461027 at 99 iterations
# the root is 955.486572 at 99 iterations
# the root is 956.523962 at 99 iterations
# the root is 957.555194 at 99 iterations
# the root is 958.568399 at 99 iterations
# the root is 959.568931 at 99 iterations
# the root is 960.573533 at 99 iterations
# the root is 961.595408 at 99 iterations
# the root is 962.631773 at 99 iterations
# the root is 963.665492 at 99 iterations
# the root is 964.682046 at 99 iterations
# the root is 965.683510 at 99 iterations
# the root is 966.685628 at 99 iterations
# the root is 967.703605 at 99 iterations
# the root is 968.738179 at 99 iterations
# the root is 969.773841 at 99 iterations
# the root is 970.793947 at 99 iterations
# the root is 971.797060 at 99 iterations
# the root is 972.797295 at 99 iterations
# the root is 973.811319 at 99 iterations
# the root is 974.843378 at 99 iterations
# the root is 975.880303 at 99 iterations
# the root is 976.903997 at 99 iterations
# the root is 977.909425 at 99 iterations
# the root is 978.908479 at 99 iterations
# the root is 979.918669 at 99 iterations
# the root is 980.947585 at 99 iterations
# the root is 981.984989 at 99 iterations
# the root is 983.012119 at 99 iterations
# the root is 984.020442 at 99 iterations
# the root is 985.019082 at 99 iterations
# the root is 986.025733 at 99 iterations
# the root is 987.051008 at 99 iterations
# the root is 988.088048 at 99 iterations
# the root is 989.118278 at 99 iterations
# the root is 990.129949 at 99 iterations
# the root is 991.128976 at 99 iterations
# the root is 992.132545 at 99 iterations
# the root is 993.153845 at 99 iterations
# the root is 994.189665 at 99 iterations
# the root is 995.222481 at 99 iterations
# the root is 996.237802 at 99 iterations
# the root is 997.238006 at 99 iterations
# the root is 998.239092 at 99 iterations
# the root is 999.256265 at 99 iterations
# the root is 1000.290051 at 99 iterations
# the root is 1001.324787 at 99 iterations
# the root is 1002.343879 at 99 iterations
# the root is 1003.346004 at 99 iterations
# the root is 1004.345314 at 99 iterations
# the root is 1005.358402 at 99 iterations
# the root is 1006.389428 at 99 iterations
# the root is 1007.425297 at 99 iterations
# the root is 1008.448091 at 99 iterations
# the root is 1009.452793 at 99 iterations
# the root is 1010.451114 at 99 iterations
# the root is 1011.460345 at 99 iterations
# the root is 1012.488017 at 99 iterations
# the root is 1013.524161 at 99 iterations
# the root is 1014.550392 at 99 iterations
# the root is 1015.558202 at 99 iterations
# the root is 1016.556357 at 99 iterations
# the root is 1017.562136 at 99 iterations
# the root is 1018.586027 at 99 iterations
# the root is 1019.621561 at 99 iterations
# the root is 1020.650780 at 99 iterations
# the root is 1021.662076 at 99 iterations
# the root is 1022.660887 at 99 iterations
# the root is 1023.663768 at 99 iterations
# the root is 1024.683636 at 99 iterations
# the root is 1025.717707 at 99 iterations
# the root is 1026.749302 at 99 iterations
# the root is 1027.764285 at 99 iterations
# the root is 1028.764528 at 99 iterations
# the root is 1029.765186 at 99 iterations
# the root is 1030.780988 at 99 iterations
# the root is 1031.812820 at 99 iterations
# the root is 1032.846052 at 99 iterations
# the root is 1033.864733 at 99 iterations
# the root is 1034.867102 at 99 iterations
# the root is 1035.866297 at 99 iterations
# the root is 1036.878180 at 99 iterations
# the root is 1037.907122 at 99 iterations
# the root is 1038.941169 at 99 iterations
# the root is 1039.963363 at 99 iterations
# the root is 1040.968436 at 99 iterations
# the root is 1041.966971 at 99 iterations
# the root is 1042.975264 at 99 iterations
# the root is 1044.000822 at 99 iterations
# the root is 1045.034824 at 99 iterations
# the root is 1046.060165 at 99 iterations
# the root is 1047.068372 at 99 iterations
# the root is 1048.067055 at 99 iterations
# the root is 1049.072241 at 99 iterations
# the root is 1050.094101 at 99 iterations
# the root is 1051.127217 at 99 iterations
# the root is 1052.155177 at 99 iterations
# the root is 1053.166777 at 99 iterations
# the root is 1054.166379 at 99 iterations
# the root is 1055.169067 at 99 iterations
# the root is 1056.187106 at 99 iterations
# the root is 1057.218559 at 99 iterations
# the root is 1058.248479 at 99 iterations

# %%
x1e = []
for i in range(len(ynn)):
    en1 = x1(ynn[i])
    x1e.append(en1)

y1e = []
for i in range(len(ynn)):
    en2 = y1(ynn[i])
    y1e.append(en2)
    
x2e = []
for i in range(len(ynn)):
    en3 = x2(ynn[i])
    x2e.append(en3)
    
y2e = []
for i in range(len(ynn)):
    en4 = y2(ynn[i])
    y2e.append(en4)

# %%
plt.plot(tv, ynn)
plt.show()

plt.plot(x1e, y1e,'ro', x2e,y2e,  'o')
plt.show()

# %% [markdown]
# (C) (7 points) Explain the method that you use to solve for ξ. Explain how an iterative method reaches a solution. Describe the convergence properties of your solutions, with reference to the number of iterations your code requires.

# %% [markdown]
# # PART C
# The Newton Raphson method uses the derivative to find a tangent line such that the tangent line will produce a root estimation.
# This method is sensative to small value of the derivative because if the derivative is close to 0 or less than 1 the root estimation diverges to infinity.
# If N-R method does not diverge, it converges quadratically.
# This method was chosen because the derivative of f(x) was easily computed.
# I set the maximum iteration to 100.
